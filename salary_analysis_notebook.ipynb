# %% [markdown]
# # Salary Prediction Analysis
#
# This notebook demonstrates a comprehensive salary prediction analysis using Python data science libraries.
#
# ## Overview
# - **Objective**: Build and evaluate machine learning models to predict employee salaries
# - **Dataset**: Synthetic salary data with realistic relationships
# - **Models**: Linear Regression and Random Forest
# - **Techniques**: EDA, Data Visualization, Feature Engineering, Model Evaluation

# %% [markdown]
# ## Setup and Imports

# %%
# Import the salary analyzer class
from salary_prediction_analysis import SalaryAnalyzer

# Import additional libraries for notebook analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use('default')
sns.set_palette("husl")

# %% [markdown]
# ## Step 1: Initialize Analyzer and Load Data

# %%
# Create analyzer instance
analyzer = SalaryAnalyzer()

# Load sample data
data = analyzer.load_data()
print(f"Dataset loaded with {len(data)} samples")

# %% [markdown]
# ## Step 2: Data Exploration

# %%
# Perform exploratory data analysis
analyzer.explore_data()

# %% [markdown]
# ## Step 3: Data Visualization

# %%
# Create comprehensive visualizations
analyzer.visualize_data()

# %% [markdown]
# ## Step 4: Prepare Data for Machine Learning

# %%
# Prepare data for modeling
X_train, X_test, y_train, y_test = analyzer.prepare_data_for_modeling()

print("Data prepared successfully!")
print(f"Training features shape: {X_train.shape}")
print(f"Test features shape: {X_test.shape}")

# %% [markdown]
# ## Step 5: Train Machine Learning Models

# %%
# Train multiple models
analyzer.train_models()

# %% [markdown]
# ## Step 6: Model Evaluation

# %%
# Evaluate and compare models
analyzer.evaluate_models()

# %% [markdown]
# ## Step 7: Feature Importance Analysis

# %%
# Analyze feature importance
analyzer.feature_importance_analysis()

# %% [markdown]
# ## Step 8: Make Predictions

# %%
# Example salary prediction for a new employee
predictions = analyzer.predict_salary(
    age=30,
    years_experience=5,
    department='Engineering',
    education_level='Bachelor',
    job_title='Mid-level',
    performance_rating=3.8,
    overtime_hours=3,
    location='Urban'
)

print("\nPrediction completed!")

# %% [markdown]
# ## Interactive Analysis Section

# %%
# Interactive prediction - Modify these values to test different scenarios
test_cases = [
    {
        'age': 25, 'years_experience': 2, 'department': 'Engineering',
        'education_level': 'Bachelor', 'job_title': 'Junior',
        'performance_rating': 3.5, 'overtime_hours': 2, 'location': 'Urban'
    },
    {
        'age': 40, 'years_experience': 15, 'department': 'Finance',
        'education_level': 'Master', 'job_title': 'Manager',
        'performance_rating': 4.5, 'overtime_hours': 8, 'location': 'Urban'
    },
    {
        'age': 50, 'years_experience': 20, 'department': 'Engineering',
        'education_level': 'PhD', 'job_title': 'Director',
        'performance_rating': 4.8, 'overtime_hours': 10, 'location': 'Urban'
    }
]

print("Testing different employee profiles:")
print("=" * 50)

for i, case in enumerate(test_cases, 1):
    print(f"\nTest Case {i}:")
    predictions = analyzer.predict_salary(**case)

# %% [markdown]
# ## Summary and Insights
#
# ### Key Findings:
# 1. **Model Performance**: Compare R² scores and error metrics between models
# 2. **Important Features**: Identify which factors most influence salary
# 3. **Salary Trends**: Understand relationships between variables and compensation
#
# ### Business Applications:
# - **HR Planning**: Set competitive salary ranges
# - **Budget Forecasting**: Predict payroll costs
# - **Career Development**: Guide employee growth paths
# - **Market Analysis**: Compare against industry standards
#
# ### Next Steps:
# - Collect real-world data to improve model accuracy
# - Add more sophisticated features (skills, certifications, etc.)
# - Implement model deployment for production use
# - Create automated reporting dashboard
