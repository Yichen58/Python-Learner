# %% [markdown]
# <a href="https://colab.research.google.com/github/Yichen58/Python-Learner/blob/main/bdas_module_1_Intro_classwork_leads_data_(Students).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Module 1 | Introduction to business analytics**
#
# # Classwork: predictive lead data

# %% [markdown]
# ## Business understanding
#
# A "lead" is a potential customer who has shown interest in your product or service. Converting leads into customers is a key goal for any business, and sales and marketing teams spend a lot of time and effort on lead generation and lead management.
#
# The "middle" part of this process is qualifying the leads. Of the many leads you have, which ones should the sales and conversion efforts focus on? How should the sales team prioritise their time and resources?
#
# A data-driven way to answer these questions is to use predictive lead scoring. Predictive lead scoring uses historical data on leads and conversions to build a model that predicts the likelihood of a lead converting. This model can then be used to prioritise the leads, so the sales team can focus on the leads that are most likely to convert.
#
# > ![Predictive lead scoring workflow](images/predictive_lead_workflow.png)
# >
# > Predictive lead scoring workflow (PyCaret, 2023)
#
# In this notebook, we will use Python to analyse a dataset of leads. We'll load and explore the data, visualise it, and understand what factors drive lead conversions.

# %% [markdown]
# ## How to use this notebook

# %% [markdown]
# The first run may take a few minutes to install the required libraries and download the data. Subsequent runs will be faster.
#
# You can also run the cells one by one using the play button next to each cell.
#
# ---
#
# This section of the notebook contains code to set up the notebook environment. It installs the required libraries, downloads the data, and sets the display style for charts.
#
# After this section of the notebook runs successfully, you can hide the cells in this section. To do this in Colab, choose **View** from the top menu, then **Collapse sections**, or click the downward chevron ⌄ next to the section title.

# %%
# Answer

# %%
# format figures for display in Canvas
sns.set_theme(style="white", rc={"figure.figsize": (12, 6)})
sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ### Upload the datasets
#
# Upload or download the leads dataset. Data file name is "leads.csv".

# %%
# Answer

# %% [markdown]
# ## Loading and viewing data
#
# We will start by loading the data and viewing the first few rows, using the `pandas` library.
#
# `pd.read_csv` reads the CSV file into a pandas dataframe, which we can then view using the `head` method.

# %%
# Answer

# %% [markdown]
# Two more useful methods are `shape` and `info`. `shape` gives the number of rows and columns in the dataset, while `info` gives the data types and number of non-null values in each column. A "null" value is a missing value, which could be due to an error in data collection or entry.

# %% [markdown]
# ***Task***
#
# How many rows and columns in the dataset?

# %%
# Answer

# %% [markdown]
# ***Task***
#
# display the columns in the dataset, their data types and non-null values (Hint: .info())

# %%
# Answer

# %% [markdown]
# ## Explatory Data Analysis - Descriptive statistics and visualisations
#
# We can use the `describe` method to view some basic statistics for numerical columns, such as count, mean, standard deviation, minimum, maximum, and quartiles.
#
# We can also use visualisations to understand the distribution of data in each column, and how different columns are related to each other. Using the `seaborn` library we can create histograms, scatter plots, and other types of plots to visualise the data.
#
# You can also do a lot more with visualisations and data storytelling in Tableau. I hope that my seaborn visualisations will inspire you to create your own visualisations in Tableau.

# %% [markdown]
# ***Task***
#
# Display a summary statistics of numerical features (hint: describe())

# %%
# Answer

# %% [markdown]
# ### Conversion rate
#
# > **Practice**: Which variable tells you whether a lead has converted or not? What is the conversion rate for this dataset?

# %% [markdown]
# ***Task***
#
# What is the average conversion rate?

# %%
# Answer

# %% [markdown]
# ***Task***
#
# Display the unique values in the `Converted` column

# %%
# Answer

# %% [markdown]
# ***Task***
#
# Display proportion of converted leads

# %%
# Answer

# %% [markdown]
# ***Task***
#
# Create a pie chart to display proportion of converted leads

# %%
# Answer

# %% [markdown]
# ### Discussion: predicting lead conversion
#
# > **Practice**: Which variables do you think are important for predicting whether a lead will convert? Why?

# %%
# display the first few 3 leads in the dataset
# transpose (rows to columns) for easier viewing

df[:3].T

# %% [markdown]
# #### Lead origin
#
# Let's try to explore these features in more detail and to understand whether they are important in predicting the conversion rate.

# %% [markdown]
# ***Task***
#
# Where do our leads come from?

# %%
# Answer

# %% [markdown]
# #### Lead source
#
# > `Lead Origin` shows the origin of leads. A different variable `Lead Source` shows the _source_ of leads. Use `value_counts` to find the most common sources of leads.

# %% [markdown]
# ***Task***
#
# Display the top 10 most common sources of leads

# %%
# Answer

# %% [markdown]
# #### Total visits
#
# >Could total number of visits to the website be a good predictor of conversion? Let's look at the distribution of
# `TotalVisits` first. What is the typical number of visits to the website?

# %% [markdown]
# ***Task***
#
# Show the distribution of TotalVisits.
#
# What is the typical number of visits to the website?

# %%
# Answer

# %% [markdown]
# **Read the interpretation** - From this information we get the mean (average) number of visits: 3.4, the median (50%/middle) number of visits: 3, and the 25-75% range: 1-5 visits. This gives us an idea of the typical number of visits to the website.

# %% [markdown]
# #### Total time spent on website and page views per visit
#
#
# ***Task***
# > Calculate basic statistics for `Total Time Spent on Website` and `Page Views Per Visit`. Use these statistics to describe the typical behaviour of visitors to the website.

# %%
# Answer

# %% [markdown]
# #### Any other important features?

# %% [markdown]
# ***Task***
#
# Identify one more features in this dataset that you think it is important for predicting conversion rate. Explain why? Describe and show the summary statistics.

# %%
# Answer

# %% [markdown]
# ### Visualisations

# %% [markdown]
# #### Bar plots
#
# The lead origin is probably important in determining whether a lead will convert. We can use a plot to visualise the number of leads by origin.

# %% [markdown]
# ***Task***
#
# Plot a bar graph to visualise the number of leads by origin

# %%
# Answer

# %% [markdown]
# ***Task***
#
# plot the distribution of leads by origin and by converted

# %%
# Answer

# %% [markdown]
# ***Task***
#
# Plot a **horizontal bar graph** to visualise the number of leads by source

# %%
# Answer

# %% [markdown]
# #### Relationship between lead origin and conversion rate
#
# We can also look at the conversion rate by lead origin. This will help us understand how the origin of the lead affects the likelihood of conversion.
#
# We will use a similar bar plot, but change the `y` variable to `Converted` to show the conversion rate instead of the count of leads.

# %% [markdown]
# ***Task***
#
# Plot the conversion rate of leads by origin.

# %%
# Answer

# %% [markdown]
# #### lead source and conversion rate
#
# ***Task***
#
# > Create a visualisation in Tableau for `Lead Source` to see how the source of leads affects conversion rate. Use whatever visualisation and filtering techniques you think are appropriate.

# %%
# Answer

# %% [markdown]
# #### total visits, page views per visit
#
# > Create a visualisation that shows the relationship between `TotalVisits` and conversion status, and `Page Views Per Visit` and conversion status. Use whatever visualisation and filtering techniques you think are appropriate.

# %% [markdown]
# **Histograms - Total visits**
#
# Does total time spent on the website affect conversion rate?
#
# Let's plot the distribution of total time spent on the website by conversion status.

# %% [markdown]
# ***Task***
#
# plot the distribution of total time spent on the website by conversion status.

# %%
# Answer

# %% [markdown]
# Clearly yes! Visitors who spend more time on the website are more likely to convert. You can see visually where the number of visits "switches over" from being indicative of non-conversion to being indicative of conversion. This looks like a good predictor of conversion. We would expect the model to assign a high importance to this variable.

# %% [markdown]
# ***Task***
#
# plot the distribution of total visits on the website by conversion status.

# %%
# Answer

# %% [markdown]
# ***Task***
#
# plot the distribution of page views per visit on the website by conversion status.

# %%
# Answer

# %% [markdown]
# #### Scatter plots
#
# Another important variable is the `Activity Score`, which measures the level of activity of the lead. We can look at how total time on website, activity score, lead origin, and conversion status are all related.
#
# We can use a scatter plot to visualise this relationship. I'm also using colour to show the conversion status of the lead, and facets (panels) to show the relationship for different lead origins.

# %% [markdown]
# ***Task***
#
# Create a scatter plot to visualise the relationship between `Total Time Spent on Website` and `Activity Score` by origin. Here we will plot only key origins API, Landing Page Submission, Lead Add Form.
#
# Hint: use relplot(kind='scatter')

# %%
# Answer

# %% [markdown]
# #### Practice: visualising relationships
#
# ***Task***
#
# > **Practice**: Create a visualisation that shows a distinct relationship between conversion and at least 2 other variables of your choice. Use whatever visualisation and filtering techniques you think are appropriate.

# %% [markdown]
# ## References
#
# Leads data adapted from https://www.kaggle.com/datasets/ashydv/leads-dataset.
