# %% [markdown]
# <a href="https://colab.research.google.com/github/Yichen58/Python-Learner/blob/main/Airbnb_Exercise_(Data_Quality)_(Student).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Airbnb

# %% [markdown]
# # Exercises on Data preparation
#
# In this notebook, we will use Airbnb dataset (source: https://www.kaggle.com/datasets/tylerx/sydney-airbnb-open-data) to prepare for predicting the price. The dataset has been modified for this exercise.

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# format figures for display in Canvas
sns.set_theme(style="white", rc={"figure.figsize": (12, 6)})
sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})

# %% [markdown]
# # Data import

# %% [markdown]
# In this exercise, we will focuse on the selected columns. Load the data and select the columns identified.

# %%
# load data using the selected columns
# DO NOT DELETE the list of columns
columns_selected = [
    'id', 'host_id', 'host_name', 'host_since',
    'host_is_superhost',
    'host_listings_count', 'host_total_listings_count',
    'host_has_profile_pic', 'host_identity_verified',
    'city', 'state', 'zipcode', 'country',
    'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
    'bed_type', 'price',
    'guests_included', 'extra_people',
    'minimum_nights', 'maximum_nights',
    'number_of_reviews', 'first_review', 'last_review',
    'review_scores_rating',
    'instant_bookable', 'cancellation_policy',
    'require_guest_profile_picture', 'require_guest_phone_verification',
]

# load the dataset and select the columns identified above.
df = pd.read_excel("Airbnb (dup sample data)v2.xlsx")
df = df[columns_selected]
df.head()
# Out:
#          id   host_id          host_name  host_since host_is_superhost  \
# 0   8851256  16357713  PropertyProviders  2014-06-04                 f
# 1  13266217  41582505              Audra  2015-08-15                 f
# 2  23614029  15879595               Kate  2014-05-23                 f
# 3  24863216   7879669             Vivian  2017-11-30                 t
# 4   5022943  25920815               Nick  2015-01-11                 f
#
#    host_listings_count  host_total_listings_count host_has_profile_pic  \
# 0                  104                        104                    t
# 1                    1                          1                    t
# 2                    1                          1                    t
# 3                    1                          1                    t
# 4                    1                          1                    t
#
#   host_identity_verified    city  ... minimum_nights  maximum_nights  \
# ...

# %% [markdown]
# # Data preparation

# %% [markdown]
# ## Initial data inspection

# %% [markdown]
# Inspect the shape and data information to check the data types

# %%
# Write your code.

# %% [markdown]
# ## Converting data types

# %% [markdown]
# There are several columns are not in the correct data type. Convert them into the appropriate data type.
#
# Below are the list of columns that needs to be fixed.
# `['host_since', 'first_review', 'last_review', 'price', 'extra_people']`

# %% [markdown]
# Show these columns in the dataframe and convert them in to the appropriate data type.

# %%
# write your code.

# %% [markdown]
# Convert date time for the following columns, `'host_since', 'first_review', 'last_review'`

# %%
# write your code.

# %% [markdown]
# Fix and convert number
#
# The issue with `['price', 'extra_people']` is that there is "`$`" sign in front of the number. You will need to remove "`$`" before converting to a number.

# %%
# write your code.

# %% [markdown]
# ## Inconsistent values

# %% [markdown]
# The column, state column has inconsistent values as shown below:
#
# `['NSW', 'New South Wales', 'Nsw', 'nsw']`
#
# Let's keep it consistent and make all values to `'NSW'`

# %%
# Write your code.

# %% [markdown]
# ## Handling missing data

# %% [markdown]
# There are several features with missing data. Handle the missing data.

# %% [markdown]
# Check missing values

# %%
# Write your code.

# %% [markdown]
# State Data - There are missing state data. As these dataset contains information about Airbnb in Sydney, all state should be NSW. Replace all the missing value with `'NSW'`

# %%
# Write your code.

# %% [markdown]
# City data - As we know the zipcode, we can find out what the city should be. Search on the internet what would be the city name? Fill the missing data based on your search.

# %%
# write your code.

# %% [markdown]
# ## Handling duplicates

# %% [markdown]
# Check and drop duplicates

# %%
# Write your code.

# %% [markdown]
# ## Handling outliers and inconsistent values

# %% [markdown]
# ### Extreme price
#
# Let's assume that we decided to remove properties with a price greater than $1500.

# %%
# Write your code.

# %% [markdown]
# ### Zero beds

# %% [markdown]
# Let's check if there are any listing that has no beds. Where do guest sleep? Is this an error?
#
# For this exercise, we will remove listing that has no beds.

# %%
# Write your code.

# %% [markdown]
# ## Encoding categoricals

# %% [markdown]
# There are several categorical features.

# %% [markdown]
# Using scikit-learn OneHotEncoder, encode the following columns `['host_is_superhost', 'host_has_profile_pic', 'host_identity_verified', 'instant_bookable', 'require_guest_profile_picture', 'require_guest_phone_verification']`. Make sure to drop the first column, and replace the main dataset with the encoded features.

# %%
# Write your code.

# %% [markdown]
# Using scikit-learn OrdinalEncoder, encode the following columns `['city', 'property_type', 'room_type', 'bed_type', 'cancellation_policy']` and replace the main dataset with the encoded features.

# %%
# Write your code.

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ## Distribution of price
#
# Visualise the distribution of price (i.e., histogram). What do you observe?

# %%
# write your code.

# %% [markdown]
# # Data summary statistics

# %% [markdown]
# ## Summary statistics

# %% [markdown]
# Let's check your cleaned and encoded dataset.

# %% [markdown]
# After the encoding, you should have the following columns.
#
# `['id', 'host_id', 'host_name', 'host_since', 'host_listings_count',
#        'host_total_listings_count', 'city', 'state', 'zipcode', 'country',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'price', 'guests_included', 'extra_people',
#        'minimum_nights', 'maximum_nights', 'number_of_reviews', 'first_review',
#        'last_review', 'review_scores_rating', 'cancellation_policy',
#        'host_is_superhost_t', 'host_has_profile_pic_t',
#        'host_identity_verified_t', 'instant_bookable_t',
#        'require_guest_profile_picture_t',
#        'require_guest_phone_verification_t']`

# %% [markdown]
# What is the average price?

# %%
# write your code.

# %% [markdown]
# What is the percentage of rooms that can be booked instantly?

# %%
# write your code.

# %% [markdown]
# What is the percentage of hosts who is identified as superhost?

# %%
# write your code.

# %% [markdown]
# Dispersion
#
# Variables that we will focus on is price.
#
# * Calculate standard deviation, range, interquartile range (IQR)
# * Plot histogram with shaded interquartile range

# %%
# write your code.

# %% [markdown]
# ## Correlation Heatmap

# %%
# write your code.

# %% [markdown]
# ## Independent Sample t-tests

# %% [markdown]
# Below are the list of t-tests we can perform. Let's test the mean differences between two groups.
# * Price differences between superhost and non-superhost.
# * Price differences between entire home and other room types.
# * Price differences between homes that we can book instant or not.
# * Price difference between high and low review ratings.
# * Price difference between hosts who had their identity verified and not verified.
# * Price difference between homes within 5km of Sydney CBD and those that are further away.

# %% [markdown]
# ### Price and Superhost

# %%
# write your code.

# %% [markdown]
# ### Price and Room type

# %%
# write your code.

# %% [markdown]
# ### Price and Instant book

# %%
# write your code.

# %% [markdown]
# ### Price and Review ratings

# %%
# write your code.

# %% [markdown]
# ### Price and Host identify verified

# %%
# write your code.

# %% [markdown]
# ### Price and Location

# %% [markdown]
# postcode within 5km of Sydney CBD (2000)
#
# This is from the website to workout the postcodes within 5km radius of Sydney CBD (2000) (https://www.freemaptools.com/find-australian-postcodes-inside-radius.htm)
#
# Below are the list of postcodes that are within 5km radius of Sydney CBD (2000)
# 1350, 2000, 2006, 2007, 2008, 2009, 2010, 2011, 2016, 2017, 2021, 2025, 2027, 2028, 2037, 2038, 2039, 2040, 2041, 2047, 2050, 2060, 2061, 2062, 2065, 2089, 2090

# %%
# write your code.
